# %%
#4174-Chaitanya Gawali                      ML-Practical-No:01                             BE-A

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/ASUS/Documents/ML-PR-DATASETS/uber/uber.csv")

# %%
df
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# ...

# %%
df = df.drop(['Unnamed: 0', 'key'], axis = 1)

# %%
df.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.shape
# Out:
# (200000, 7)

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        200000 non-null  float64
#  1   pickup_datetime    200000 non-null  object
#  2   pickup_longitude   200000 non-null  float64
#  3   pickup_latitude    200000 non-null  float64
#  4   dropoff_longitude  199999 non-null  float64
#  5   dropoff_latitude   199999 non-null  float64
#  6   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 10.7+ MB

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  200000.000000     200000.000000    200000.000000      199999.000000
# mean       11.359955        -72.527638        39.935885         -72.525292
# std         9.901776         11.437787         7.720539          13.117408
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963658
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count
# count     199999.000000    200000.000000
# mean          39.923890         1.684535
# std            6.794829         1.385997
# min         -881.985513         0.000000
# 25%           40.733823         1.000000
# 50%           40.753042         1.000000
# ...

# %%
#Filling Missing Values

# %%
df.isnull()
# Out:
#         fare_amount  pickup_datetime  pickup_longitude  pickup_latitude  \
# 0             False            False             False            False
# 1             False            False             False            False
# 2             False            False             False            False
# 3             False            False             False            False
# 4             False            False             False            False
# ...             ...              ...               ...              ...
# 199995        False            False             False            False
# 199996        False            False             False            False
# 199997        False            False             False            False
# 199998        False            False             False            False
# 199999        False            False             False            False
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 2

# %%
#Column pickup_datetime is in the wrong format (Object). Convert it to DateTime format.

# %%
df.pickup_datetime = pd.to_datetime(df.pickup_datetime, errors='coerce', utc=True)

# %%
df.dtypes
# Out:
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                float64
# dropoff_latitude                 float64
# passenger_count                    int64
# dtype: object

# %%
df.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df = df.assign(hour = df.pickup_datetime.dt.hour, 
                day = df.pickup_datetime.dt.day,
              month = df.pickup_datetime.dt.month,
               year = df.pickup_datetime.dt.year,
              dayofweek = df.pickup_datetime.dt.dayofweek,
              dayName = df.pickup_datetime.dt.day_name())

# %%
df.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  hour  day  month  \
# 0         -73.999512         40.723217                1    19    7      5
# 1         -73.994710         40.750325                1    20   17      7
# 2         -73.962565         40.772647                1    21   24      8
# 3         -73.965316         40.803349                3     8   26      6
# 4         -73.973082         40.761247                5    17   28      8
#
#    year  dayofweek   dayName
# 0  2015          3  Thursday
# ...

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  200000.000000     200000.000000    200000.000000      199999.000000
# mean       11.359955        -72.527638        39.935885         -72.525292
# std         9.901776         11.437787         7.720539          13.117408
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963658
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count           hour            day  \
# count     199999.000000    200000.000000  200000.000000  200000.000000
# mean          39.923890         1.684535      13.491335      15.704670
# std            6.794829         1.385997       6.515531       8.687409
# ...

# %%
x = df['fare_amount'].value_counts()

# %%
print(type(x))
print("Max Count = ", x[6.50])
x
# Out:
# <class 'pandas.core.series.Series'>
# Max Count =  9684
# 6.50      9684
# 4.50      8247
# 8.50      7521
# 5.70      5858
# 5.30      5838
#           ...
# 140.25       1
# 190.00       1
# 45.16        1
# 28.20        1
# 89.10        1
# Name: fare_amount, Length: 1244, dtype: int64

# %%
df = df.drop('pickup_datetime', axis=1)

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 0         40.723217                1    19    7      5  2015          3
# 1         40.750325                1    20   17      7  2009          4
# 2         40.772647                1    21   24      8  2009          0
# 3         40.803349                3     8   26      6  2009          4
# 4         40.761247                5    17   28      8  2014          3
#
#     dayName
# 0  Thursday
# 1    Friday
# 2    Monday
# 3    Friday
# 4  Thursday

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# hour                   int64
# day                    int64
# month                  int64
# year                   int64
# dayofweek              int64
# dayName               object
# dtype: object

# %%
df.drop(['dayName'],axis=1, inplace=True)

# %%
number_of_columns = len(df.columns)

# %%
number_of_columns
# Out:
# 11

# %%
df.plot(kind="box", subplots=False, layout=(8, 2), figsize=(17, 20))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="box", subplots=True, layout=(8, 2), figsize=(17, 20))
# Out:
# fare_amount             AxesSubplot(0.125,0.798085;0.352273x0.0819149)
# pickup_longitude     AxesSubplot(0.547727,0.798085;0.352273x0.0819149)
# pickup_latitude         AxesSubplot(0.125,0.699787;0.352273x0.0819149)
# dropoff_longitude    AxesSubplot(0.547727,0.699787;0.352273x0.0819149)
# dropoff_latitude        AxesSubplot(0.125,0.601489;0.352273x0.0819149)
# passenger_count      AxesSubplot(0.547727,0.601489;0.352273x0.0819149)
# hour                    AxesSubplot(0.125,0.503191;0.352273x0.0819149)
# day                  AxesSubplot(0.547727,0.503191;0.352273x0.0819149)
# month                   AxesSubplot(0.125,0.404894;0.352273x0.0819149)
# year                 AxesSubplot(0.547727,0.404894;0.352273x0.0819149)
# dayofweek               AxesSubplot(0.125,0.306596;0.352273x0.0819149)
# dtype: object

# %%
df.plot(kind="box", subplots=True, layout=(4, 3), figsize=(15, 20))
# Out:
# fare_amount             AxesSubplot(0.125,0.712609;0.227941x0.167391)
# pickup_longitude     AxesSubplot(0.398529,0.712609;0.227941x0.167391)
# pickup_latitude      AxesSubplot(0.672059,0.712609;0.227941x0.167391)
# dropoff_longitude       AxesSubplot(0.125,0.511739;0.227941x0.167391)
# dropoff_latitude     AxesSubplot(0.398529,0.511739;0.227941x0.167391)
# passenger_count      AxesSubplot(0.672059,0.511739;0.227941x0.167391)
# hour                     AxesSubplot(0.125,0.31087;0.227941x0.167391)
# day                   AxesSubplot(0.398529,0.31087;0.227941x0.167391)
# month                 AxesSubplot(0.672059,0.31087;0.227941x0.167391)
# year                        AxesSubplot(0.125,0.11;0.227941x0.167391)
# dayofweek                AxesSubplot(0.398529,0.11;0.227941x0.167391)
# dtype: object

# %%
#Explanation of Clip Function

# %%
a = np.arange(10,100,10)
a1 = np.clip(a,30,60)

# %%
print("Before Clipping :", a)
print("After Clipping :", a1)
# Out:
# Before Clipping : [10 20 30 40 50 60 70 80 90]
# After Clipping : [30 30 30 40 50 60 60 60 60]

# %%
#Eliminations of Outliers

# %%
def remove_outlier(df1, col):
    Q1 = df1[col].quantile(0.25)
    Q2 = df1[col].quantile(0.50)
    Q3 = df1[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_whisker = Q1-1.5*IQR
    upper_whisker = Q3+1.5*IQR
    print("-----*******************************************-----")
    print("col=", col, "Q1=", Q1, "Q2=", Q2, "Q3=", Q3)
    print("-----*******************************************-----")
    df[col] = np.clip(df1[col] , lower_whisker , upper_whisker)
    return df1

def treat_outliers_all(df1, col_list):
    print("col_list", col_list)
    for i in col_list:
        df1 = remove_outlier(df1, i)
    return df1
df = treat_outliers_all(df, df.columns)
# Out:
# col_list Index(['fare_amount', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'hour',
#        'day', 'month', 'year', 'dayofweek'],
#       dtype='object')
# -----*******************************************-----
# col= fare_amount Q1= 6.0 Q2= 8.5 Q3= 12.5
# -----*******************************************-----
# -----*******************************************-----
# col= pickup_longitude Q1= -73.992065 Q2= -73.98182299999999 Q3= -73.96715350000001
# -----*******************************************-----
# -----*******************************************-----
# col= pickup_latitude Q1= 40.73479575 Q2= 40.752592 Q3= 40.767158
# -----*******************************************-----
# -----*******************************************-----
# col= dropoff_longitude Q1= -73.991407 Q2= -73.98009300000001 Q3= -73.9636585
# -----*******************************************-----
# -----*******************************************-----
# ...

# %%
df.plot(kind = "box",subplots = True,layout = (7,2),figsize=(15,20))
# Out:
# fare_amount             AxesSubplot(0.125,0.786098;0.352273x0.0939024)
# pickup_longitude     AxesSubplot(0.547727,0.786098;0.352273x0.0939024)
# pickup_latitude         AxesSubplot(0.125,0.673415;0.352273x0.0939024)
# dropoff_longitude    AxesSubplot(0.547727,0.673415;0.352273x0.0939024)
# dropoff_latitude        AxesSubplot(0.125,0.560732;0.352273x0.0939024)
# passenger_count      AxesSubplot(0.547727,0.560732;0.352273x0.0939024)
# hour                    AxesSubplot(0.125,0.448049;0.352273x0.0939024)
# day                  AxesSubplot(0.547727,0.448049;0.352273x0.0939024)
# month                   AxesSubplot(0.125,0.335366;0.352273x0.0939024)
# year                 AxesSubplot(0.547727,0.335366;0.352273x0.0939024)
# dayofweek               AxesSubplot(0.125,0.222683;0.352273x0.0939024)
# dtype: object

# %%
# !pip install haversine

# %%
import haversine as hs

# %%
travel_dist = []
for pos in range(len(df['pickup_longitude'])):
    long1, lati1, long2, lati2 = [df['pickup_longitude'][pos], df['pickup_latitude'][pos], df['dropoff_longitude'][pos], df['dropoff_latitude'][pos]]
    loc1 = (lati1, long1)
    loc2 = (lati2, long2)
    c = hs.haversine(loc1, loc2)
    travel_dist.append(c)
print(travel_dist)
df['dist_travel_km'] = travel_dist
df.head()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.929786        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 0         40.723217              1.0    19    7      5  2015          3
# 1         40.750325              1.0    20   17      7  2009          4
# ...

# %%
df = df[(df.dist_travel_km >= 1) & (df.dist_travel_km <= 130)]
print("Remaining observations in the dataset: ",df.shape)
# Out:
# Remaining observations in the dataset:  (163039, 12)

# %%
bool_df = df.isnull()
bool_df
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             False             False            False              False
# 1             False             False            False              False
# 2             False             False            False              False
# 3             False             False            False              False
# 4             False             False            False              False
# ...             ...               ...              ...                ...
# 199994        False             False            False              False
# 199996        False             False            False              False
# 199997        False             False            False              False
# 199998        False             False            False              False
# 199999        False             False            False              False
#
#         dropoff_latitude  passenger_count   hour    day  month   year  \
# ...

# %%
#Finding Incorrect latitude(Less than or greater than 90) and longitude(Greater than or less than 180)

# %%
incorrect_coordinates = df.loc[(df.pickup_latitude > 90) |(df.pickup_latitude < -90) 
                               |(df.dropoff_latitude > 90) |(df.dropoff_latitude < -90) 
                               |(df.pickup_longitude > 180) |(df.pickup_longitude < -180) 
                               |(df.dropoff_longitude > 90) |(df.dropoff_longitude < -90)]

# %%
df.drop(incorrect_coordinates, inplace = True, errors = 'ignore')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_29404\2959381030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(incorrect_coordinates, inplace = True, errors = 'ignore')

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.929786        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 0         40.723217              1.0    19    7      5  2015          3
# 1         40.750325              1.0    20   17      7  2009          4
# 2         40.772647              1.0    21   24      8  2009          0
# 3         40.803349              3.0     8   26      6  2009          4
# 4         40.761247              3.5    17   28      8  2014          3
#
#    dist_travel_km
# 0        1.683325
# 1        2.457593
# 2        5.036384
# 3        1.661686
# 4        4.116088

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# hour                 0
# day                  0
# month                0
# year                 0
# dayofweek            0
# dist_travel_km       0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(bool_df.corr())
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\matrix.py:198: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\matrix.py:203: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <AxesSubplot:>

# %%
corr = df.corr()
corr
# Out:
#                    fare_amount  pickup_longitude  pickup_latitude  \
# fare_amount           1.000000          0.193161        -0.119486
# pickup_longitude      0.193161          1.000000         0.425303
# pickup_latitude      -0.119486          0.425303         1.000000
# dropoff_longitude     0.258590          0.241571         0.148762
# dropoff_latitude     -0.137716          0.169231         0.358862
# passenger_count       0.015078         -0.012876        -0.016174
# hour                 -0.029740          0.013071         0.031495
# day                   0.001628         -0.004445         0.002919
# month                 0.031337          0.000861         0.001625
# year                  0.161854          0.014856        -0.016177
# dayofweek             0.009278         -0.028383        -0.044611
# dist_travel_km        0.798922          0.129977        -0.143562
#
#                    dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
plt.subplots(figsize =(12,8))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['fare_amount', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'hour',
#        'day', 'month', 'year', 'dayofweek', 'dist_travel_km'],
#       dtype='object')

# %%
x = df[df.columns[1:]]

# %%
x
# Out:
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# 2             -74.005043        40.740770         -73.962565
# 3             -73.976124        40.790844         -73.965316
# 4             -73.929786        40.744085         -73.973082
# ...                  ...              ...                ...
# 199994        -73.983070        40.760770         -73.972972
# 199996        -73.984722        40.736837         -74.006672
# 199997        -73.986017        40.756487         -73.922036
# 199998        -73.997124        40.725452         -73.983215
# 199999        -73.984395        40.720077         -73.985508
#
#         dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 0              40.723217              1.0    19    7      5  2015          3
# ...

# %%
y = df['fare_amount']
y
# Out:
# 0          7.50
# 1          7.70
# 2         12.90
# 3          5.30
# 4         16.00
#           ...
# 199994    12.00
# 199996     7.50
# 199997    22.25
# 199998    14.50
# 199999    14.10
# Name: fare_amount, Length: 163039, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size = 0.70, random_state=0)

# %%
X_train
# Out:
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 22328         -74.010145        40.729243         -73.984576
# 25017         -73.991362        40.753357         -73.997152
# 17056         -73.983397        40.762530         -73.946870
# 70104         -74.006783        40.730999         -73.950256
# 120815        -73.974358        40.758060         -73.954895
# ...                  ...              ...                ...
# 119819        -73.961427        40.774487         -73.975972
# 117728        -73.929786        40.771057         -73.977167
# 186929        -73.995506        40.759931         -73.965811
# 144682        -73.968471        40.754760         -73.982818
# 53466         -74.001520        40.707280         -73.992397
#
#         dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 22328          40.743874              1.0    13   30      1  2012          0
# ...

# %%
X_test
# Out:
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 130217        -74.009324        40.729096         -74.008022
# 63774         -74.003173        40.727731         -73.954923
# 160892        -73.978247        40.754007         -74.008607
# 129891        -73.994582        40.726154         -73.998903
# 24008         -73.984868        40.755830         -74.014070
# ...                  ...              ...                ...
# 19452         -73.987943        40.743932         -73.981425
# 6417          -73.929786        40.686252         -73.977187
# 189791        -73.969490        40.763369         -73.947313
# 33384         -73.975212        40.792282         -73.961227
# 27312         -73.959399        40.781247         -73.975849
#
#         dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 130217         40.740215              1.0    19   28      6  2010          0
# ...

# %%
Y_train
# Out:
# 22328     11.30
# 25017     10.00
# 17056     10.50
# 70104     22.25
# 120815     9.00
#           ...
# 119819     6.50
# 117728    22.25
# 186929     8.90
# 144682     5.30
# 53466     16.10
# Name: fare_amount, Length: 48911, dtype: float64

# %%
Y_test
# Out:
# 130217     5.3
# 63774     17.3
# 160892    12.5
# 129891     5.0
# 24008     13.7
#           ...
# 19452      9.7
# 6417      12.5
# 189791     7.3
# 33384      6.5
# 27312      4.9
# Name: fare_amount, Length: 114128, dtype: float64

# %%
len(y)
# Out:
# 163039

# %%
len(Y_train)
# Out:
# 48911

# %%
len(Y_test)
# Out:
# 114128

# %%
len(Y_train) + len(Y_test)
# Out:
# 163039

# %%
#Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
regression.intercept_
# Out:
# 3781.6607326755457

# %%
regression.coef_
# Out:
# array([ 2.68711423e+01, -6.75093541e+00,  2.18681283e+01, -1.83508835e+01,
#         6.34591709e-02,  9.53080500e-03,  1.09017648e-03,  6.15811891e-02,
#         4.23245288e-01, -4.41361683e-02,  1.80923514e+00])

# %%
for i in range(0, len(regression.coef_)):
    print("theta", i, "=", regression.coef_[i])
# Out:
# theta 0 = 26.871142313841734
# theta 1 = -6.750935406910438
# theta 2 = 21.86812829889894
# theta 3 = -18.35088347931836
# theta 4 = 0.06345917093183406
# theta 5 = 0.009530805004363258
# theta 6 = 0.0010901764811387855
# theta 7 = 0.06158118906572108
# theta 8 = 0.42324528760992897
# theta 9 = -0.044136168287923314
# theta 10 = 1.8092351440002563

# %%
y_pred = regression.predict(X_test)

# %%
comparision = pd.DataFrame({"Actual Label":Y_test, "Predicted Label":y_pred})

# %%
comparision
# Out:
#         Actual Label  Predicted Label
# 130217           5.3         5.563571
# 63774           17.3        17.961562
# 160892          12.5        13.621671
# 129891           5.0         6.750603
# 24008           13.7        15.420892
# ...              ...              ...
# 19452            9.7         7.856686
# 6417            12.5        27.228560
# 189791           7.3         9.197015
# 33384            6.5         8.051301
# 27312            4.9         7.072066
#
# [114128 rows x 2 columns]

# %%
comparision.reset_index()
# Out:
#          index  Actual Label  Predicted Label
# 0       130217           5.3         5.563571
# 1        63774          17.3        17.961562
# 2       160892          12.5        13.621671
# 3       129891           5.0         6.750603
# 4        24008          13.7        15.420892
# ...        ...           ...              ...
# 114123   19452           9.7         7.856686
# 114124    6417          12.5        27.228560
# 114125  189791           7.3         9.197015
# 114126   33384           6.5         8.051301
# 114127   27312           4.9         7.072066
#
# [114128 rows x 3 columns]

# %%
comparision.reset_index().drop(["index"], axis=1)
# Out:
#         Actual Label  Predicted Label
# 0                5.3         5.563571
# 1               17.3        17.961562
# 2               12.5        13.621671
# 3                5.0         6.750603
# 4               13.7        15.420892
# ...              ...              ...
# 114123           9.7         7.856686
# 114124          12.5        27.228560
# 114125           7.3         9.197015
# 114126           6.5         8.051301
# 114127           4.9         7.072066
#
# [114128 rows x 2 columns]

# %%
sns.heatmap(comparision.corr())
# Out:
# <AxesSubplot:>

# %%
#Metrics Evaluation using R2, Mean Squared Error, Root Mean Squared Error

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test, y_pred)
# Out:
# 0.6803370537056113

# %%
from sklearn.metrics import mean_squared_error

# %%
MSE = mean_squared_error(Y_test, y_pred)

# %%
MSE
# Out:
# 9.145815834655565

# %%
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 3.024204992168283

# %%
#Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 100)

# %%
rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(X_test)

# %%
y_pred
# Out:
# array([ 5.442 , 17.7132, 16.2925, ...,  7.416 ,  5.68  ,  6.15  ])

# %%
#Metrics Evaluation for Random Forest

# %%
R2_Random = r2_score(Y_test, y_pred)
R2_Random
# Out:
# 0.8199271308243812

# %%
MSE_Random = mean_squared_error(Y_test, y_pred)

# %%
MSE_Random
# Out:
# 5.152030654130101

# %%
RMSE_Random = np.sqrt(MSE_Random)

# %%
RMSE_Random
# Out:
# 2.269808506048495
